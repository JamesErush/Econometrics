# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %%
import scipy.stats as sci

# %%
data = pd.read_excel(r'C:\Users\tim39\Downloads\caschool.xlsx')  # load data set
X = data.iloc[:, 0].values.reshape(-1, 1)  # values converts it into a numpy array
Y = data.iloc[:, 1].values.reshape(-1, 1)  # -1 means that calculate the dimension of rows, but have 1 column
linear_regressor = LinearRegression()  # create object for the class
linear_regressor.fit(X, Y)  # perform linear regression
Y_pred = linear_regressor.predict(X)  # make predictions

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %%
print(linear_regressor.intercept_)
# Out:
# [66682.72865098]

# %%
print(linear_regressor.coef_)
# Out:
# [[3.75335332]]

# %%
data.var()
# Out:
# Observation Number    1.473500e+04
# dist_cod              1.202005e+07
# enrl_tot              1.531239e+07
# teachers              3.531118e+04
# calw_pct              1.312129e+02
# meal_pct              7.356778e+02
# computer              1.947821e+05
# testscr               3.630301e+02
# comp_stu              4.219257e-03
# expn_stu              4.018762e+05
# str                   3.578952e+00
# avginc                5.221348e+01
# el_pct                3.343751e+02
# read_scr              4.043309e+02
# math_scr              3.517201e+02
# dtype: float64
